# %% [markdown]
# # working with json

# %%
import pandas as pd

# %%
df = pd.read_json('https://microsoftedge.github.io/Demos/json-dummy-data/64KB.json)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # working with MySQL

# %%
# !pip install mysql-connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
host="127.0.0.1",
database = 'world',
    password = ''
   )
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'ODBC'@'localhost' (using password: NO)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 conn = mysql.connector.connect(
#       2 host="127.0.0.1",
#       3 database = 'world',
#       4     password = ''
#       5    )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
# ...

# %%
conn

# %%
import pandas as pd
df = pd.read_sql_query('select * from city' , conn)

# %%
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
df.shape
# Out:
# (4079, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4079 entries, 0 to 4078
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4079 non-null   int64
#  1   Name         4079 non-null   object
#  2   CountryCode  4079 non-null   object
#  3   District     4079 non-null   object
#  4   Population   4079 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 159.5+ KB

# %% [markdown]
# # working with API

# %%
# !python -m pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNjQ1YzNiYjBlYjdjODViM2NjNTIxYzQyNDU3YWI3YyIsIm5iZiI6MTc4MDg0NTIzNC40NzgwMDAyLCJzdWIiOiI2YTI1OGFiMjE4OGE1OTMyOTQ2MzEyZDEiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.T9aDmUvVlFXfwILgapG5v-lbqloEJeCLAltAZ0xyFsw"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg', 'genre_ids': [12, 16, 10751, 14], 'id': 1007757, 'title': 'Swapped', 'original_language': 'en', 'original_title': 'Swapped', 'overview': 'A small woodland creature and a majestic bird, two natural sworn enemies of the Valley, magically trade places and set off on an adventure of a lifetime to switch back. Their journey soon uncovers a greater threat—one that could endanger not only their species, but the entire valley they call home.', 'popularity': 216.3932, 'poster_path': '/tHhxWxge06goXU6ZQH1hj7vK8Hd.jpg', 'release_date': '2026-05-01', 'softcore': False, 'video': False, 'vote_average': 8.979, 'vote_count': 1599}, {'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'title': 'The Shawshank Redemption', 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his w
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','original_language','overview','popularity']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df = pd.DataFrame(response.json()['results'])[['id','title','release_date','original_language','overview','popularity']]
#
# KeyError: 'results'

# %%
df
# Out:
#          id                                          title release_date  \
# 0   1007757                                        Swapped   2026-05-01
# 1       278                       The Shawshank Redemption   1994-09-23
# 2       238                                  The Godfather   1972-03-14
# 3    687163                              Project Hail Mary   2026-03-15
# 4       240                          The Godfather Part II   1974-12-20
# 5       424                               Schindler's List   1993-12-15
# 6       389                                   12 Angry Men   1957-04-10
# 7   1330021                    Remarkably Bright Creatures   2026-05-07
# 8       129                                  Spirited Away   2001-07-20
# 9       155                                The Dark Knight   2008-07-16
# 10    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 11      497                                 The Green Mile   1999-12-10
# ...

# %%
df.shape
# Out:
# (20, 6)

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNjQ1YzNiYjBlYjdjODViM2NjNTIxYzQyNDU3YWI3YyIsIm5iZiI6MTc4MDg0NTIzNC40NzgwMDAyLCJzdWIiOiI2YTI1OGFiMjE4OGE1OTMyOTQ2MzEyZDEiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.T9aDmUvVlFXfwILgapG5v-lbqloEJeCLAltAZ0xyFsw"
}

# %%
dfs = []

# %%
for i in range(1,547):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}', headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','release_date','original_language','overview','popularity']]
    dfs.append(temp_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 3
#       1 for i in range(1,547):
#       2     response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}', headers=headers)
# ----> 3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','release_date','original_language','overview','popularity']]
#       4     dfs.append(temp_df)
#
# KeyError: 'results'

# %%
print("x")

# %%
df = pd.concat(dfs,ignore_index = True)

# %%
df
