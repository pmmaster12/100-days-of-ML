# %% [markdown]
# # 1. Libray Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# 2. EDA

# %%
df = pd.read_csv('concrete_data.csv')

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
# 3. Train-Test Split for transformation and Tranining

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,0:8], df['Strength'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((824, 8), (206, 8))

# %%
Y_train
# Out:
# 995    27.68
# 507    62.05
# 334    23.80
# 848    33.40
# 294     7.40
#        ...
# 87     24.40
# 330    42.22
# 466    33.56
# 121    68.30
# 860    38.46
# Name: Strength, Length: 824, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lr.predict(X_test)
r2_score(Y_test, Y_pred)
# Out:
# 0.6275531792314848

# %%
# 4. checking with cross - validation

# %%
# Cross checking with cross val score
lr = LinearRegression()
np.mean(cross_val_score(lr,X_train,Y_train,scoring='r2'))
# Out:
# np.float64(0.5946055391992532)

# %%
# 5. Plotting PDF AND QQ PLOT BEFORE TRANSFORMATION

# %%
# Plotting the distplots without any transformation

for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.histplot(X_train[col], kde=True, color ="green")
    plt.title(col)

    plt.subplot(122)
    stats.probplot(X_train[col], dist="norm", plot=plt)
    plt.title(col)

    plt.show()

# %%
# 6. BOX - COX

# %%
pt = PowerTransformer(method= 'box-cox')
h = 0.0000001
X_train_box_cox = pt.fit_transform(X_train + h)
X_test_box_cox = pt.transform(X_test + h)

# %%
# Out:
# numpy.ndarray

# %%
pd.DataFrame({'cols': X_train.columns, 'box_cox_lambdas': pt.lambdas_})
# Out:
#                  cols  box_cox_lambdas
# 0              Cement         0.177025
# 1  Blast Furnace Slag         0.022767
# 2             Fly Ash        -0.034635
# 3               Water         0.772682
# 4    Superplasticizer         0.087141
# 5    Coarse Aggregate         1.129813
# 6      Fine Aggregate         1.782018
# 7                 Age         0.066631

# %%
# Applying linear regression on transformed data

lr = LinearRegression()
lr.fit(X_train_box_cox,Y_train)

y_pred2 = lr.predict(X_test_box_cox)

r2_score(Y_test,y_pred2)
# Out:
# 0.8042534503877324

# %%
lr = LinearRegression()
np.mean(cross_val_score(lr,X_train_box_cox,Y_train,scoring='r2'))
# Out:
# np.float64(0.7922924852277534)

# %%
# 7.  Before and after comparision for Box-Cox Plot

# %%
# Before and after comparision for Box-Cox Plot
X_train_transformed = pd.DataFrame(X_train_box_cox,columns=X_train.columns)

for col in X_train_transformed.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.histplot(X_train[col], kde=True)
    plt.title(col)

    plt.subplot(122)
    sns.histplot(X_train_transformed[col], kde =True)
    plt.title(col)

    plt.show()

# %%
# 9. YE- JOHNSON

# %%
# Apply Yeo-Johnson transform
pt1 = PowerTransformer()

X_train_transformed2 = pt1.fit_transform(X_train)
X_test_transformed2 = pt1.transform(X_test)

lr = LinearRegression()
lr.fit(X_train_transformed2,Y_train)

y_pred3 = lr.predict(X_test_transformed2)

print(r2_score(Y_test,y_pred3))

pd.DataFrame({'cols':X_train.columns,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
# 0.8161906510869553
#                  cols  Yeo_Johnson_lambdas
# 0              Cement             0.174348
# 1  Blast Furnace Slag             0.015715
# 2             Fly Ash            -0.161447
# 3               Water             0.771307
# 4    Superplasticizer             0.253935
# 5    Coarse Aggregate             1.130050
# 6      Fine Aggregate             1.783100
# 7                 Age             0.019885

# %%
lr = LinearRegression()
np.mean(cross_val_score(lr,X_train_transformed2,Y_train,scoring='r2'))
# Out:
# np.float64(0.7941782179212531)

# %%
X_train_transformed2 = pd.DataFrame(X_train_transformed2,columns=X_train.columns)

# %%
X_train_transformed2
# Out:
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0   -1.279751            1.018168  1.130993 -0.301917          1.250424
# 1    1.244813            0.222584  1.166671 -0.165051          0.643937
# 2    0.079751           -1.056928  1.143637 -1.047299          0.796163
# 3   -0.145770            0.835725  1.009268  0.581232          0.585508
# 4   -1.131111            0.487511  1.150162 -1.105305          0.886463
# ..        ...                 ...       ...       ...               ...
# 819  0.183530            1.146737 -0.884932 -1.769937          0.924953
# 820 -0.198870           -1.056928  1.151932 -1.839142          0.999192
# 821 -0.844661           -1.056928  1.152152 -0.706091          0.796163
# 822  1.565741            0.921796 -0.884932 -0.019305          0.689050
# 823  0.426534           -1.056928  1.123673 -0.543872          0.806465
#
#      Coarse Aggregate  Fine Aggregate       Age
# 0           -0.262504       -0.677567  0.105778
# ...

# %%
# 9. Before and after comparision for Yeo-Johnson

# %%
# Before and after comparision for Yeo-Johnson

for col in X_train_transformed2.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.histplot(X_train[col], kde = True)
    plt.title(col)

    plt.subplot(122)
    sns.histplot(X_train_transformed2[col], kde=True)
    plt.title(col)

    plt.show()

# %%
# 10. Side by side Lambdas

# %%
# Side by side Lambdas
pd.DataFrame({'cols':X_train.columns,'box_cox_lambdas':pt.lambdas_,'Yeo_Johnson_lambdas':pt1.lambdas_})
# Out:
#                  cols  box_cox_lambdas  Yeo_Johnson_lambdas
# 0              Cement         0.177025             0.174348
# 1  Blast Furnace Slag         0.022767             0.015715
# 2             Fly Ash        -0.034635            -0.161447
# 3               Water         0.772682             0.771307
# 4    Superplasticizer         0.087141             0.253935
# 5    Coarse Aggregate         1.129813             1.130050
# 6      Fine Aggregate         1.782018             1.783100
# 7                 Age         0.066631             0.019885
