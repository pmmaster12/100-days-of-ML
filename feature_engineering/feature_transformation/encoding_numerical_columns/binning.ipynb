# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('train.csv', usecols=['Age','Fare','SibSp','Parch','Survived'])

# %%
df
# Out:
#      Survived   Age  SibSp  Parch     Fare
# 0           0  22.0      1      0   7.2500
# 1           1  38.0      1      0  71.2833
# 2           1  26.0      0      0   7.9250
# 3           1  35.0      1      0  53.1000
# 4           0  35.0      0      0   8.0500
# ..        ...   ...    ...    ...      ...
# 886         0  27.0      0      0  13.0000
# 887         1  19.0      0      0  30.0000
# 888         0   NaN      1      2  23.4500
# 889         1  26.0      0      0  30.0000
# 890         0  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      Survived   Age  SibSp  Parch     Fare
# 0           0  22.0      1      0   7.2500
# 1           1  38.0      1      0  71.2833
# 2           1  26.0      0      0   7.9250
# 3           1  35.0      1      0  53.1000
# 4           0  35.0      0      0   8.0500
# ..        ...   ...    ...    ...      ...
# 885         0  39.0      0      5  29.1250
# 886         0  27.0      0      0  13.0000
# 887         1  19.0      0      0  30.0000
# 889         1  26.0      0      0  30.0000
# 890         0  32.0      0      0   7.7500
#
# [714 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Survived    0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
df.sample(5)
# Out:
#      Survived    Age  SibSp  Parch      Fare
# 305         1   0.92      1      2  151.5500
# 677         1  18.00      0      0    9.8417
# 371         0  18.00      1      0    6.4958
# 34          0  28.00      1      0   82.1708
# 686         0  14.00      4      1   39.6875

# %%
df['family'] = df ['SibSp'] + df['Parch']

# %%
df.sample(10)
# Out:
#      Survived   Age  SibSp  Parch     Fare  family
# 385         0  18.0      0      0  73.5000       0
# 125         1  12.0      1      0  11.2417       1
# 234         0  24.0      0      0  10.5000       0
# 521         0  22.0      0      0   7.8958       0
# 871         1  47.0      1      1  52.5542       2
# 701         1  35.0      0      0  26.2875       0
# 282         0  16.0      0      0   9.5000       0
# 508         0  28.0      0      0  22.5250       0
# 169         0  28.0      0      0  56.4958       0
# 34          0  28.0      1      0  82.1708       1

# %%
df.drop(columns=['SibSp','Parch'],inplace=True)

# %%
df.head()
# Out:
#    Survived   Age     Fare  family
# 0         0  22.0   7.2500       1
# 1         1  38.0  71.2833       1
# 2         1  26.0   7.9250       0
# 3         1  35.0  53.1000       1
# 4         0  35.0   8.0500       0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df.drop(columns='Survived'), 
                                                 df['Survived'],test_size=0.2,random_state=42)

# %%
X_train.shape , X_test.shape
# Out:
# ((571, 3), (143, 3))

# %%
X_train.head()
# Out:
#       Age     Fare  family
# 328  31.0  20.5250       2
# 73   26.0  14.4542       1
# 253  30.0  16.1000       1
# 719  33.0   7.7750       0
# 666  25.0  13.0000       0

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = clf.predict(X_test)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.6433566433566433

# %%
np.mean(cross_val_score(DecisionTreeClassifier(),X_train,Y_train,cv=10,scoring='accuracy'))
# Out:
# np.float64(0.6637931034482759)

# %%
# Binning

# %%
kbin_age = KBinsDiscretizer(n_bins=15,encode='ordinal',strategy='quantile')
kbin_fare = KBinsDiscretizer(n_bins=15,encode='ordinal',strategy='quantile')

# %%
trf = ColumnTransformer([
    ('first',kbin_age,[0]),
    ('second',kbin_fare,[1])
], remainder='passthrough')

# %%
X_train_trf = trf.fit_transform(X_train)
X_test_trf = trf.transform(X_test)

# %%
X_train_trf
# Out:
# array([[ 8.,  8.,  2.],
#        [ 6.,  7.,  1.],
#        [ 8.,  7.,  1.],
#        ...,
#        [11., 14.,  0.],
#        [ 9.,  8.,  2.],
#        [ 9.,  3.,  0.]], shape=(571, 3))

# %%
trf
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('first',
#                                  KBinsDiscretizer(encode='ordinal', n_bins=15),
#                                  [0]),
#                                 ('second',
#                                  KBinsDiscretizer(encode='ordinal', n_bins=15),
#                                  [1])])

# %%
trf.named_transformers_['first'].bin_edges_
# Out:
# array([array([ 0.42,  6.  , 16.  , 19.  , 21.  , 23.  , 25.  , 28.  , 30.  ,
#               32.  , 35.  , 38.  , 42.  , 47.  , 54.  , 80.  ])             ],
#       dtype=object)

# %%
trf.named_transformers_['second'].bin_edges_
# Out:
# array([array([  0.    ,   7.25  ,   7.775 ,   7.8958,   8.1583,  10.5   ,
#                13.    ,  14.4542,  18.75  ,  26.    ,  26.55  ,  31.275 ,
#                51.4792,  76.2917, 108.9   , 512.3292])                   ],
#       dtype=object)

# %%
output = pd.DataFrame({
    'age':X_train['Age'],
    'age_trf':X_train_trf[:,0],
    'fare':X_train['Fare'],
    'fare_trf':X_train_trf[:,1]
})

# %%
output['age_labels'] = pd.cut(x=X_train['Age'],
                                    bins=trf.named_transformers_['first'].bin_edges_[0].tolist())
output['fare_labels'] = pd.cut(x=X_train['Fare'],
                                    bins=trf.named_transformers_['second'].bin_edges_[0].tolist())

# %%
output.sample(5)
# Out:
#       age  age_trf     fare  fare_trf    age_labels       fare_labels
# 35   42.0     12.0   52.000      12.0  (38.0, 42.0]  (51.479, 76.292]
# 297   2.0      0.0  151.550      14.0   (0.42, 6.0]  (108.9, 512.329]
# 693  25.0      6.0    7.225       0.0  (23.0, 25.0]       (0.0, 7.25]
# 526  50.0     13.0   10.500       5.0  (47.0, 54.0]     (8.158, 10.5]
# 340   2.0      0.0   26.000       9.0   (0.42, 6.0]     (18.75, 26.0]

# %%
X_train_trf
# Out:
# array([[ 8.,  8.,  2.],
#        [ 6.,  7.,  1.],
#        [ 8.,  7.,  1.],
#        ...,
#        [11., 14.,  0.],
#        [ 9.,  8.,  2.],
#        [ 9.,  3.,  0.]], shape=(571, 3))

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train_trf,Y_train)
Y_pred2 = clf.predict(X_test_trf)

# %%
accuracy_score(Y_test,Y_pred2)
# Out:
# 0.6363636363636364

# %%
np.mean(cross_val_score(DecisionTreeClassifier(),X_train_trf,Y_train,cv=10,scoring='accuracy'))
# Out:
# np.float64(0.6532062915910466)

# %%
Y_train
# Out:
# 328    1
# 73     0
# 253    0
# 719    0
# 666    0
#       ..
# 92     0
# 134    0
# 337    1
# 548    0
# 130    0
# Name: Survived, Length: 571, dtype: int64

# %%
def discretize(bins,strategy):
    kbin_age = KBinsDiscretizer(n_bins=bins,encode='ordinal',strategy=strategy)
    kbin_fare = KBinsDiscretizer(n_bins=bins,encode='ordinal',strategy=strategy)
    
    trf = ColumnTransformer([
        ('first',kbin_age,[0]),
        ('second',kbin_fare,[1])
    ], remainder='passthrough')
    
    # X_train_trf = trf.fit_transform(X_train)
    # X_test_trf = trf.transform(X_test)

    pipe = Pipeline([
    ('preprocessor', trf),
    ('classifier', DecisionTreeClassifier())
])
    scores = cross_val_score(pipe, X_train, Y_train, cv=10, scoring='accuracy')

    print("CV Accuracy:", scores.mean())

    X_train_trf = trf.fit_transform(X_train)

    plt.figure(figsize=(14,4))
    plt.subplot(121)
    plt.hist(X_train['Age'])
    plt.title("Before")

    plt.subplot(122)
    plt.hist(X_train_trf[:,0],color='red')
    plt.title("After")

    plt.show()
    
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    plt.hist(X_train['Fare'])
    plt.title("Before")

    plt.subplot(122)
    plt.hist(X_train_trf[:,1],color='red')
    plt.title("Fare")

    plt.show()

# %%
discretize(15,'kmeans')
# Out:
# CV Accuracy: 0.6603750756200847
