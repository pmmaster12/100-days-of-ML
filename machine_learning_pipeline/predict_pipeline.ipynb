# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipeline_trained.pkl', 'rb'))

# %%
grid = pickle.load(open('hyperParameter_tuned_trained.pkl', 'rb'))

# %%
test_input1 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict_proba(test_input1)
# Out:
# D:\personal\coharts\100 days of ml\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# D:\personal\coharts\100 days of ml\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([[0.83333333, 0.16666667]])

# %%
grid.predict_proba(test_input1)
# Out:
# D:\personal\coharts\100 days of ml\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# D:\personal\coharts\100 days of ml\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([[0.87619048, 0.12380952]])
